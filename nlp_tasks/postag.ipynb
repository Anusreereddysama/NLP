# %%
## Speech Of DR APJ Abdul Kalam

paragraph = """I have three visions for India. In 3000 years of our history, people from all over 

               the world have come and invaded us, captured our lands, conquered our minds. 

               From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,

               the French, the Dutch, all of them came and looted us, took over what was ours. 

               Yet we have not done this to any other nation. We have not conquered anyone. 

               We have not grabbed their land, their culture, 

               their history and tried to enforce our way of life on them. 

               Why? Because we respect the freedom of others.That is why my 

               first vision is that of freedom. I believe that India got its first vision of 

               this in 1857, when we started the War of Independence. It is this freedom that

               we must protect and nurture and build on. If we are not free, no one will respect us.

               My second vision for India’s development. For fifty years we have been a developing nation.

               It is time we see ourselves as a developed nation. We are among the top 5 nations of the world

               in terms of GDP. We have a 10 percent growth rate in most areas. Our poverty levels are falling.

               Our achievements are being globally recognised today. Yet we lack the self-confidence to

               see ourselves as a developed nation, self-reliant and self-assured. Isn’t this incorrect?

               I have a third vision. India must stand up to the world. Because I believe that unless India 

               stands up to the world, no one will respect us. Only strength respects strength. We must be 

               strong not only as a military power but also as an economic power. Both must go hand-in-hand. 

               My good fortune was to have worked with three great minds. Dr. Vikram Sarabhai of the Dept. of 

               space, Professor Satish Dhawan, who succeeded him and Dr. Brahm Prakash, father of nuclear material.

               I was lucky to have worked with all three of them closely and consider this the great opportunity of my life. 

               I see four milestones in my career"""

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

sentences=sent_tokenize(paragraph)
sentences
# Out:
# ['I have three visions for India.',
#  'In 3000 years of our history, people from all over \n\n               the world have come and invaded us, captured our lands, conquered our minds.',
#  'From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,\n\n               the French, the Dutch, all of them came and looted us, took over what was ours.',
#  'Yet we have not done this to any other nation.',
#  'We have not conquered anyone.',
#  'We have not grabbed their land, their culture, \n\n               their history and tried to enforce our way of life on them.',
#  'Why?',
#  'Because we respect the freedom of others.That is why my \n\n               first vision is that of freedom.',
#  'I believe that India got its first vision of \n\n               this in 1857, when we started the War of Independence.',
#  'It is this freedom that\n\n               we must protect and nurture and build on.',
#  'If we are not free, no one will respect us.',
#  'My second vision for India’s development.',
#  'For fifty years we have been a developing nation.',
#  'It is time we see ourselves as a developed nation.',
#  'We are among the top 5 nations of the world\n\n               in terms of GDP.',
#  'We have a 10 percent growth rate in most areas.',
#  'Our poverty levels are falling.',
#  'Our achievements are being globally recognised today.',
#  'Yet we lack the self-confidence to\n\n               see ourselves as a developed nation, self-reliant and self-assured.',
#  'Isn’t this incorrect?',
#  'I have a third vision.',
#  'India must stand up to the world.',
#  'Because I believe that unless India \n\n               stands up to the world, no one will respect us.',
#  'Only strength respects strength.',
#  'We must be \n\n               strong not only as a military power but also as an economic power.',
#  'Both must go hand-in-hand.',
#  'My good fortune was to have worked with three great minds.',
#  'Dr. Vikram Sarabhai of the Dept.',
#  'of \n\n               space, Professor Satish Dhawan, who succeeded him and Dr. Brahm Prakash, father of nuclear material.',
#  'I was lucky to have worked with all three of them closely and consider this the great opportunity of my life.',
#  'I see four milestones in my career']

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/anusreereddysama/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/anusreereddysama/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/anusreereddysama/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk import pos_tag
for i in range(len(sentences)):
    words=word_tokenize(sentences[i])
    words=[w for w in words if w.lower() not in set(stopwords.words('english'))]
    pos_tags = pos_tag(words)
    print( pos_tags)
# Out:
# [('three', 'CD'), ('visions', 'NNS'), ('India', 'NNP'), ('.', '.')]
# [('3000', 'CD'), ('years', 'NNS'), ('history', 'NN'), (',', ','), ('people', 'NNS'), ('world', 'NN'), ('come', 'VBP'), ('invaded', 'VBN'), ('us', 'PRP'), (',', ','), ('captured', 'VBD'), ('lands', 'NNS'), (',', ','), ('conquered', 'VBD'), ('minds', 'NNS'), ('.', '.')]
# [('Alexander', 'NNP'), ('onwards', 'NNS'), (',', ','), ('Greeks', 'NNP'), (',', ','), ('Turks', 'NNP'), (',', ','), ('Moguls', 'NNP'), (',', ','), ('Portuguese', 'NNP'), (',', ','), ('British', 'NNP'), (',', ','), ('French', 'NNP'), (',', ','), ('Dutch', 'NNP'), (',', ','), ('came', 'VBD'), ('looted', 'JJ'), ('us', 'PRP'), (',', ','), ('took', 'VBD'), ('.', '.')]
# [('Yet', 'RB'), ('done', 'VBN'), ('nation', 'NN'), ('.', '.')]
# [('conquered', 'VBN'), ('anyone', 'NN'), ('.', '.')]
# [('grabbed', 'JJ'), ('land', 'NN'), (',', ','), ('culture', 'NN'), (',', ','), ('history', 'NN'), ('tried', 'VBD'), ('enforce', 'JJ'), ('way', 'NN'), ('life', 'NN'), ('.', '.')]
# [('?', '.')]
# [('respect', 'NN'), ('freedom', 'NN'), ('others.That', 'IN'), ('first', 'JJ'), ('vision', 'NN'), ('freedom', 'NN'), ('.', '.')]
# [('believe', 'VB'), ('India', 'NNP'), ('got', 'VBD'), ('first', 'JJ'), ('vision', 'NN'), ('1857', 'CD'), (',', ','), ('started', 'VBD'), ('War', 'NNP'), ('Independence', 'NNP'), ('.', '.')]
# [('freedom', 'NN'), ('must', 'MD'), ('protect', 'VB'), ('nurture', 'NN'), ('build', 'NN'), ('.', '.')]
# [('free', 'JJ'), (',', ','), ('one', 'CD'), ('respect', 'NN'), ('us', 'PRP'), ('.', '.')]
# [('second', 'JJ'), ('vision', 'NN'), ('India', 'NNP'), ('’', 'NNP'), ('development', 'NN'), ('.', '.')]
# [('fifty', 'JJ'), ('years', 'NNS'), ('developing', 'VBG'), ('nation', 'NN'), ('.', '.')]
# [('time', 'NN'), ('see', 'VB'), ('developed', 'JJ'), ('nation', 'NN'), ('.', '.')]
# [('among', 'IN'), ('top', 'JJ'), ('5', 'CD'), ('nations', 'NNS'), ('world', 'NN'), ('terms', 'NNS'), ('GDP', 'NNP'), ('.', '.')]
# [('10', 'CD'), ('percent', 'JJ'), ('growth', 'NN'), ('rate', 'NN'), ('areas', 'NNS'), ('.', '.')]
# [('poverty', 'NN'), ('levels', 'NNS'), ('falling', 'VBG'), ('.', '.')]
# [('achievements', 'NNS'), ('globally', 'RB'), ('recognised', 'VBN'), ('today', 'NN'), ('.', '.')]
# [('Yet', 'RB'), ('lack', 'JJ'), ('self-confidence', 'NN'), ('see', 'NN'), ('developed', 'JJ'), ('nation', 'NN'), (',', ','), ('self-reliant', 'JJ'), ('self-assured', 'JJ'), ('.', '.')]
# [('’', 'NN'), ('incorrect', 'NN'), ('?', '.')]
# [('third', 'JJ'), ('vision', 'NN'), ('.', '.')]
# [('India', 'NNP'), ('must', 'MD'), ('stand', 'VB'), ('world', 'NN'), ('.', '.')]
# [('believe', 'VB'), ('unless', 'IN'), ('India', 'NNP'), ('stands', 'VBZ'), ('world', 'NN'), (',', ','), ('one', 'CD'), ('respect', 'NN'), ('us', 'PRP'), ('.', '.')]
# [('strength', 'NN'), ('respects', 'NNS'), ('strength', 'NN'), ('.', '.')]
# [('must', 'MD'), ('strong', 'JJ'), ('military', 'JJ'), ('power', 'NN'), ('also', 'RB'), ('economic', 'JJ'), ('power', 'NN'), ('.', '.')]
# [('must', 'MD'), ('go', 'VB'), ('hand-in-hand', 'NN'), ('.', '.')]
# [('good', 'JJ'), ('fortune', 'NN'), ('worked', 'VBD'), ('three', 'CD'), ('great', 'JJ'), ('minds', 'NNS'), ('.', '.')]
# [('Dr.', 'NNP'), ('Vikram', 'NNP'), ('Sarabhai', 'NNP'), ('Dept', 'NNP'), ('.', '.')]
# [('space', 'NN'), (',', ','), ('Professor', 'NNP'), ('Satish', 'NNP'), ('Dhawan', 'NNP'), (',', ','), ('succeeded', 'VBD'), ('Dr.', 'NNP'), ('Brahm', 'NNP'), ('Prakash', 'NNP'), (',', ','), ('father', 'RB'), ('nuclear', 'JJ'), ('material', 'NN'), ('.', '.')]
# [('lucky', 'JJ'), ('worked', 'VBD'), ('three', 'CD'), ('closely', 'RB'), ('consider', 'VBP'), ('great', 'JJ'), ('opportunity', 'NN'), ('life', 'NN'), ('.', '.')]
# [('see', 'VB'), ('four', 'CD'), ('milestones', 'NNS'), ('career', 'NN')]

# %%
for i in range(len(sentences)):
    print(sentences[i])
# Out:
# three visions India .
# 3000 years history , people world come invaded us , captured lands , conquered minds .
# Alexander onwards , Greeks , Turks , Moguls , Portuguese , British , French , Dutch , came looted us , took .
# Yet done nation .
# conquered anyone .
# grabbed land , culture , history tried enforce way life .
# ?
# respect freedom others.That first vision freedom .
# believe India got first vision 1857 , started War Independence .
# freedom must protect nurture build .
# free , one respect us .
# second vision India ’ development .
# fifty years developing nation .
# time see developed nation .
# among top 5 nations world terms GDP .
# 10 percent growth rate areas .
# poverty levels falling .
# achievements globally recognised today .
# Yet lack self-confidence see developed nation , self-reliant self-assured .
# ’ incorrect ?
# third vision .
# India must stand world .
# believe unless India stands world , one respect us .
# strength respects strength .
# must strong military power also economic power .
# must go hand-in-hand .
# good fortune worked three great minds .
# Dr. Vikram Sarabhai Dept .
# space , Professor Satish Dhawan , succeeded Dr. Brahm Prakash , father nuclear material .
# lucky worked three closely consider great opportunity life .
# see four milestones career

# %%
paragraph = """I have three visions for students. First, the vision of waking up early. Every student sets an alarm for 5:00 AM with great confidence. But when the alarm rings, suddenly the pillow becomes the most important relationship in life. The snooze button becomes the best friend, and the dream becomes more important than the future. Yet somehow, five more minutes magically becomes fifty. Still, we promise ourselves, “Tomorrow I will wake up early.”
 
My second vision is about exams. Before exams, students become philosophers. We say, “Marks are just numbers. True knowledge matters.” But the moment results are announced, we refresh the website 27 times in one minute. Suddenly, even one mark feels like national importance. We promise again, “Next semester I will start studying from day one.” Of course, day one never arrives.
 
My third vision is about assignments. Assignments are given one month before submission. For twenty-nine days, we respect them from a distance. On the last night, we discover hidden superpowers. Coffee becomes our energy source, Google becomes our guru, and teamwork means copying with coordination. And yet, despite all this chaos, students always survive, laugh, learn, and move forward.
 
That is the true strength of students - we may procrastinate, we may panic, but in the end, we somehow manage. And that, my friends, is our hidden talent."""

sentences=sent_tokenize(paragraph)
sentences
# Out:
# ['I have three visions for students.',
#  'First, the vision of waking up early.',
#  'Every student sets an alarm for 5:00 AM with great confidence.',
#  'But when the alarm rings, suddenly the pillow becomes the most important relationship in life.',
#  'The snooze button becomes the best friend, and the dream becomes more important than the future.',
#  'Yet somehow, five more minutes magically becomes fifty.',
#  'Still, we promise ourselves, “Tomorrow I will wake up early.”\n \nMy second vision is about exams.',
#  'Before exams, students become philosophers.',
#  'We say, “Marks are just numbers.',
#  'True knowledge matters.” But the moment results are announced, we refresh the website 27 times in one minute.',
#  'Suddenly, even one mark feels like national importance.',
#  'We promise again, “Next semester I will start studying from day one.” Of course, day one never arrives.',
#  'My third vision is about assignments.',
#  'Assignments are given one month before submission.',
#  'For twenty-nine days, we respect them from a distance.',
#  'On the last night, we discover hidden superpowers.',
#  'Coffee becomes our energy source, Google becomes our guru, and teamwork means copying with coordination.',
#  'And yet, despite all this chaos, students always survive, laugh, learn, and move forward.',
#  'That is the true strength of students - we may procrastinate, we may panic, but in the end, we somehow manage.',
#  'And that, my friends, is our hidden talent.']

# %%
from nltk.stem import PorterStemmer
stemming=PorterStemmer()
for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    words=[stemming.stem(word) for word in words if word.lower() not in set(stopwords.words('english'))]
    sentences[i]=" ".join(words)
for i in range(len(sentences)):
    print(sentences[i])

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    words=[lemmatizer.lemmatize(word,pos='v') for word in words if word not in set(stopwords.words('english'))]
    sentences[i]=" ".join(words)
    
for i in range(len(sentences)):
    print(sentences[i])
# Out:
# three vision student .
# first , vision wake earli .
# everi student set alarm 5:00 great confid .
# alarm ring , suddenli pillow becom import relationship life .
# snooz button becom best friend , dream becom import futur .
# yet somehow , five minut magic becom fifti .
# still , promis , “ tomorrow wake early . ” second vision exam .
# exam , student becom philosoph .
# say , “ mark number .
# true knowledg matter . ” moment result announc , refresh websit 27 time one minut .
# suddenli , even one mark feel like nation import .
# promis , “ next semest start studi day one . ” cours , day one never arriv .
# third vision assign .
# assign give one month submiss .
# twenty-nin day , respect distanc .
# last night , discov hide superpow .
# coffe becom energi sourc , googl becom guru , teamwork mean copi coordin .
# yet , despit chao , student alway surviv , laugh , learn , move forward .
# true strength student - may procrastin , may panic , end , somehow manag .
# , friend , hide talent .

# %%
for i in range(len(sentences)):
    words=word_tokenize(sentences[i])
    words=[w for w in words if w.lower() not in set(stopwords.words('english'))]
    pos_tags = pos_tag(words)
    print( pos_tags)
# Out:
# [('three', 'CD'), ('vision', 'NN'), ('student', 'NN'), ('.', '.')]
# [('first', 'RB'), (',', ','), ('vision', 'NN'), ('wake', 'NN'), ('earli', 'NN'), ('.', '.')]
# [('everi', 'JJ'), ('student', 'NN'), ('set', 'VBN'), ('alarm', 'RB'), ('5:00', 'CD'), ('great', 'JJ'), ('confid', 'NN'), ('.', '.')]
# [('alarm', 'NN'), ('ring', 'NN'), (',', ','), ('suddenli', 'JJ'), ('pillow', 'NN'), ('becom', 'NN'), ('import', 'NN'), ('relationship', 'NN'), ('life', 'NN'), ('.', '.')]
# [('snooz', 'JJ'), ('button', 'NN'), ('becom', 'NN'), ('best', 'JJS'), ('friend', 'NN'), (',', ','), ('dream', 'NN'), ('becom', 'NN'), ('import', 'NN'), ('futur', 'NN'), ('.', '.')]
# [('yet', 'RB'), ('somehow', 'RB'), (',', ','), ('five', 'CD'), ('minut', 'NN'), ('magic', 'NN'), ('becom', 'NN'), ('fifti', 'NN'), ('.', '.')]
# [('still', 'RB'), (',', ','), ('promis', 'NN'), (',', ','), ('“', 'NNP'), ('tomorrow', 'NN'), ('wake', 'VBP'), ('early', 'JJ'), ('.', '.'), ('”', 'JJ'), ('second', 'JJ'), ('vision', 'NN'), ('exam', 'NN'), ('.', '.')]
# [('exam', 'NN'), (',', ','), ('student', 'NN'), ('becom', 'NN'), ('philosoph', 'NN'), ('.', '.')]
# [('say', 'NN'), (',', ','), ('“', 'JJ'), ('mark', 'NN'), ('number', 'NN'), ('.', '.')]
# [('true', 'JJ'), ('knowledg', 'NN'), ('matter', 'NN'), ('.', '.'), ('”', 'CC'), ('moment', 'NN'), ('result', 'NN'), ('announc', 'NN'), (',', ','), ('refresh', 'JJ'), ('websit', 'NN'), ('27', 'CD'), ('time', 'NN'), ('one', 'CD'), ('minut', 'NN'), ('.', '.')]
# [('suddenli', 'NN'), (',', ','), ('even', 'RB'), ('one', 'CD'), ('mark', 'NN'), ('feel', 'NN'), ('like', 'IN'), ('nation', 'NN'), ('import', 'NN'), ('.', '.')]
# [('promis', 'NN'), (',', ','), ('“', 'NNP'), ('next', 'JJ'), ('semest', 'JJS'), ('start', 'JJ'), ('studi', 'NN'), ('day', 'NN'), ('one', 'CD'), ('.', '.'), ('”', 'NN'), ('cours', 'NNS'), (',', ','), ('day', 'NN'), ('one', 'CD'), ('never', 'RB'), ('arriv', 'NN'), ('.', '.')]
# [('third', 'JJ'), ('vision', 'NN'), ('assign', 'NN'), ('.', '.')]
# [('assign', 'RB'), ('give', 'JJ'), ('one', 'CD'), ('month', 'NN'), ('submiss', 'NN'), ('.', '.')]
# [('twenty-nin', 'JJ'), ('day', 'NN'), (',', ','), ('respect', 'NN'), ('distanc', 'NN'), ('.', '.')]
# [('last', 'JJ'), ('night', 'NN'), (',', ','), ('discov', 'NN'), ('hide', 'NN'), ('superpow', 'NN'), ('.', '.')]
# [('coffe', 'NN'), ('becom', 'NN'), ('energi', 'NN'), ('sourc', 'NN'), (',', ','), ('googl', 'NN'), ('becom', 'NN'), ('guru', 'NN'), (',', ','), ('teamwork', 'NN'), ('mean', 'JJ'), ('copi', 'NN'), ('coordin', 'NN'), ('.', '.')]
# [('yet', 'RB'), (',', ','), ('despit', 'NN'), ('chao', 'NN'), (',', ','), ('student', 'NN'), ('alway', 'RB'), ('surviv', 'RB'), (',', ','), ('laugh', 'NN'), (',', ','), ('learn', 'NN'), (',', ','), ('move', 'VB'), ('forward', 'RB'), ('.', '.')]
# [('true', 'JJ'), ('strength', 'NN'), ('student', 'NN'), ('-', ':'), ('may', 'MD'), ('procrastin', 'VB'), (',', ','), ('may', 'MD'), ('panic', 'VB'), (',', ','), ('end', 'VB'), (',', ','), ('somehow', 'RB'), ('manag', 'NN'), ('.', '.')]
# [(',', ','), ('friend', 'NN'), (',', ','), ('hide', 'VB'), ('talent', 'NN'), ('.', '.')]
